# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
d = pd.read_csv('processedData.csv')
d
# Out:
#         X1   X2   X3   X4   X5   X6   X7   X8   X9  X10  ...  X170  X171  \
# 0      135  190  229  223  192  125   55   -9  -33  -38  ...   -17   -15
# 1      386  382  356  331  320  315  307  272  244  232  ...   164   150
# 2      -32  -39  -47  -37  -32  -36  -57  -73  -85  -94  ...    57    64
# 3     -105 -101  -96  -92  -89  -95 -102 -100  -87  -79  ...   -82   -81
# 4       -9  -65  -98 -102  -78  -48  -16    0  -21  -59  ...     4     2
# ...    ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...   ...   ...
# 11495  -22  -22  -23  -26  -36  -42  -45  -42  -45  -49  ...    15    16
# 11496  -47  -11   28   77  141  211  246  240  193  136  ...   -65   -33
# 11497   14    6  -13  -16   10   26   27   -9    4   14  ...   -65   -48
# 11498  -40  -25   -9  -12   -2   12    7   19   22   29  ...   121   135
# 11499   29   41   57   72   74   62   54   43   31   23  ...   -59   -25
#
#        X172  X173  X174  X175  X176  X177  X178  class
# ...

# %%
plt.subplot(511)
plt.plot(d.iloc[1,0:178].to_numpy())  
#this indexing removes label column
#to numpy is required for better compatibility with matplotlib
plt.title('Examples of classes (top to bottom: class 1 to  class 5)')
plt.ylabel('uV')
plt.subplot(512)
plt.ylabel('uV')
plt.plot(d.iloc[7,0:178].to_numpy())
plt.subplot(513)
plt.ylabel('uV')
plt.plot(d.iloc[12,0:178].to_numpy())
plt.subplot(514)
plt.ylabel('uV')
plt.plot(d.iloc[0,0:178].to_numpy())
plt.subplot(515)
plt.plot(d.iloc[2,0:178].to_numpy())
plt.ylabel('uV')
plt.xlabel('Samples')
# Out:
# Text(0.5, 0, 'Samples')

# %%
#Examples of each of the five classes of data. Top to bottom: class 1, class 2, class 3, class 4, class 5
